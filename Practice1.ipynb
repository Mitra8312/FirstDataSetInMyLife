# %%
import pandas as pd 
import numpy as np
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('vgsales_22.csv')
df
# Out:
#       Rank                                      Name Platform    Year
# 0    14378      Hajime no Ippo: The Fighting! (2014)      PS3  2014.0  \
# 1    14260           Garfield: A Tale of Two Kitties       DS  2006.0
# 2     9891                                  ArmA III       PC  2013.0
# 3     5958                         RealSports Boxing     2600  1986.0
# 4     7095                  Bratz: Girlz Really Rock      PS2  2008.0
# ..     ...                                       ...      ...     ...
# 548   8560  Summon Night EX-Thesis: Yoake no Tsubasa      PS2  2005.0
# 549   3815                Go Diego Go! Safari Rescue      Wii  2008.0
# 550   2718                                   FIFA 15      Wii  2014.0
# 551   1093                            Monsters, Inc.      GBA  2001.0
# 552    967                                  NBA 2K11      PS3  2010.0
#
#             Genre             Publisher  NA_Sales  EU_Sales  JP_Sales
# ...

# %%
df.head()
# Out:
#     Rank                                  Name Platform    Year     Genre
# 0  14378  Hajime no Ippo: The Fighting! (2014)      PS3  2014.0    Sports  \
# 1  14260       Garfield: A Tale of Two Kitties       DS  2006.0  Platform
# 2   9891                              ArmA III       PC  2013.0   Shooter
# 3   5958                     RealSports Boxing     2600  1986.0    Sports
# 4   7095              Bratz: Girlz Really Rock      PS2  2008.0    Action
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0   Namco Bandai Games      0.00      0.00      0.03         0.00  \
# 1         Game Factory      0.03      0.00      0.00         0.00
# 2  Bohemia Interactive      0.00      0.10      0.00         0.02
# 3                Atari      0.28      0.02      0.00         0.00
# 4                  THQ      0.11      0.09      0.00         0.03
#
#    Global_Sales
# 0          0.03
# 1          0.03
# 2          0.12
# 3          0.29
# 4          0.23

# %%
df.tail()
# Out:
#      Rank                                      Name Platform    Year
# 548  8560  Summon Night EX-Thesis: Yoake no Tsubasa      PS2  2005.0  \
# 549  3815                Go Diego Go! Safari Rescue      Wii  2008.0
# 550  2718                                   FIFA 15      Wii  2014.0
# 551  1093                            Monsters, Inc.      GBA  2001.0
# 552   967                                  NBA 2K11      PS3  2010.0
#
#             Genre             Publisher  NA_Sales  EU_Sales  JP_Sales
# 548  Role-Playing             Banpresto      0.00      0.00      0.16  \
# 549        Action  Take-Two Interactive      0.48      0.01      0.00
# 550        Sports       Electronic Arts      0.24      0.46      0.00
# 551     Adventure                   THQ      0.59      0.95      0.03
# 552        Action  Take-Two Interactive      1.41      0.21      0.03
#
#      Other_Sales  Global_Sales
# 548         0.00          0.16
# 549         0.04          0.53
# 550         0.06          0.76
# ...

# %%
df.shape
# Out:
# (553, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          553 non-null    int64
#  1   Name          553 non-null    object
#  2   Platform      553 non-null    object
#  3   Year          546 non-null    float64
#  4   Genre         553 non-null    object
#  5   Publisher     549 non-null    object
#  6   NA_Sales      553 non-null    float64
#  7   EU_Sales      553 non-null    float64
#  8   JP_Sales      553 non-null    float64
#  9   Other_Sales   553 non-null    float64
#  10  Global_Sales  553 non-null    float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 47.6+ KB

# %%
df.describe()
# Out:
#                Rank         Year    NA_Sales    EU_Sales    JP_Sales
# count    553.000000   546.000000  553.000000  553.000000  553.000000  \
# mean    8346.528029  2006.648352    0.287975    0.162351    0.091591
# std     4758.183395     5.881472    0.919362    0.507089    0.376682
# min       16.000000  1980.000000    0.000000    0.000000    0.000000
# 25%     4527.000000  2003.000000    0.000000    0.000000    0.000000
# 50%     8049.000000  2008.000000    0.080000    0.020000    0.000000
# 75%    12520.000000  2010.000000    0.210000    0.090000    0.040000
# max    16566.000000  2016.000000   14.970000    5.050000    5.380000
#
#        Other_Sales  Global_Sales
# count   553.000000    553.000000
# mean      0.047306      0.589096
# std       0.148114      1.692039
# min       0.000000      0.010000
# 25%       0.000000      0.060000
# 50%       0.010000      0.180000
# 75%       0.030000      0.430000
# max       2.010000     21.820000

# %%
df = df.drop("Other_Sales", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = df.drop("Other_Sales", axis=1)
#       2 df
#
# File c:\Users\igogo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5266, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5118 def drop(
#    5119     self,
#    5120     labels: IndexLabel = None,
#    (...)
#    5127     errors: IgnoreRaise = "raise",
#    5128 ) -> DataFrame | None:
#    5129     """
#    5130     Drop specified labels from rows or columns.
#    5131
#    (...)
#    5264             weight  1.0     0.8
#    5265     """
# -> 5266     return super().drop(
#    5267         labels=labels,
#    5268         axis=axis,
#    5269         index=index,
#    5270         columns=columns,
#    5271         level=level,
#    5272         inplace=inplace,
# ...

# %%
df
# Out:
#       Rank                                      Name Platform    Year
# 0    14378      Hajime no Ippo: The Fighting! (2014)      PS3  2014.0  \
# 1    14260           Garfield: A Tale of Two Kitties       DS  2006.0
# 2     9891                                  ArmA III       PC  2013.0
# 3     5958                         RealSports Boxing     2600  1986.0
# 4     7095                  Bratz: Girlz Really Rock      PS2  2008.0
# ..     ...                                       ...      ...     ...
# 548   8560  Summon Night EX-Thesis: Yoake no Tsubasa      PS2  2005.0
# 549   3815                Go Diego Go! Safari Rescue      Wii  2008.0
# 550   2718                                   FIFA 15      Wii  2014.0
# 551   1093                            Monsters, Inc.      GBA  2001.0
# 552    967                                  NBA 2K11      PS3  2010.0
#
#             Genre             Publisher  NA_Sales  EU_Sales  JP_Sales
# ...

# %%
df['Platform'] = df['Platform'].replace({"PC": "Компуктер"})
df
# Out:
#       Rank                                      Name   Platform    Year
# 0    14378      Hajime no Ippo: The Fighting! (2014)        PS3  2014.0  \
# 1    14260           Garfield: A Tale of Two Kitties         DS  2006.0
# 2     9891                                  ArmA III  Компуктер  2013.0
# 3     5958                         RealSports Boxing       2600  1986.0
# 4     7095                  Bratz: Girlz Really Rock        PS2  2008.0
# ..     ...                                       ...        ...     ...
# 548   8560  Summon Night EX-Thesis: Yoake no Tsubasa        PS2  2005.0
# 549   3815                Go Diego Go! Safari Rescue        Wii  2008.0
# 550   2718                                   FIFA 15        Wii  2014.0
# 551   1093                            Monsters, Inc.        GBA  2001.0
# 552    967                                  NBA 2K11        PS3  2010.0
#
#             Genre             Publisher  NA_Sales  EU_Sales  JP_Sales
# ...

# %%
imputer = SimpleImputer(strategy='mean')
df['Year'] = imputer.fit_transform(df[['Year']])
df
# Out:
#       Rank                                      Name   Platform    Year
# 0    14378      Hajime no Ippo: The Fighting! (2014)        PS3  2014.0  \
# 1    14260           Garfield: A Tale of Two Kitties         DS  2006.0
# 2     9891                                  ArmA III  Компуктер  2013.0
# 3     5958                         RealSports Boxing       2600  1986.0
# 4     7095                  Bratz: Girlz Really Rock        PS2  2008.0
# ..     ...                                       ...        ...     ...
# 548   8560  Summon Night EX-Thesis: Yoake no Tsubasa        PS2  2005.0
# 549   3815                Go Diego Go! Safari Rescue        Wii  2008.0
# 550   2718                                   FIFA 15        Wii  2014.0
# 551   1093                            Monsters, Inc.        GBA  2001.0
# 552    967                                  NBA 2K11        PS3  2010.0
#
#             Genre             Publisher  NA_Sales  EU_Sales  JP_Sales
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          553 non-null    int64
#  1   Name          553 non-null    object
#  2   Platform      553 non-null    object
#  3   Year          553 non-null    float64
#  4   Genre         553 non-null    object
#  5   Publisher     549 non-null    object
#  6   NA_Sales      553 non-null    float64
#  7   EU_Sales      553 non-null    float64
#  8   JP_Sales      553 non-null    float64
#  9   Global_Sales  553 non-null    float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 43.3+ KB

# %%
df.to_csv('Yoyoyoy.csv', index=False)
